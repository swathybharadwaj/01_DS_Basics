# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
pd.__version__
# Out:
# '1.0.5'

# %%
data=pd.read_csv("churn_prediction.csv")

# %%
data.head()
# Out:
#    customer_id  vintage  age gender  dependents     occupation    city  \
# 0            1     2101   66   Male         0.0  self_employed   187.0
# 1            2     2348   35   Male         0.0  self_employed     NaN
# 2            4     2194   31   Male         0.0       salaried   146.0
# 3            5     2329   90    NaN         NaN  self_employed  1020.0
# 4            6     1579   42   Male         2.0  self_employed  1494.0
#
#    customer_nw_category  branch_code  current_balance  ...  \
# 0                     2          755          1458.71  ...
# 1                     2         3214          5390.37  ...
# 2                     2           41          3913.16  ...
# 3                     2          582          2291.91  ...
# 4                     3          388           927.72  ...
#
#    average_monthly_balance_prevQ  average_monthly_balance_prevQ2  \
# 0                        1458.71                         1449.07
# ...

# %%
data.shape
# Out:
# (28382, 21)

# %%
data.describe()
# Out:
#         customer_id       vintage           age    dependents          city  \
# count  28382.000000  28382.000000  28382.000000  25919.000000  27579.000000
# mean   15143.508667   2091.144105     48.208336      0.347236    796.109576
# std     8746.454456    272.676775     17.807163      0.997661    432.872102
# min        1.000000     73.000000      1.000000      0.000000      0.000000
# 25%     7557.250000   1958.000000     36.000000      0.000000    409.000000
# 50%    15150.500000   2154.000000     46.000000      0.000000    834.000000
# 75%    22706.750000   2292.000000     60.000000      0.000000   1096.000000
# max    30301.000000   2476.000000     90.000000     52.000000   1649.000000
#
#        customer_nw_category   branch_code  current_balance  \
# count          28382.000000  28382.000000     2.838200e+04
# mean               2.225530    925.975019     7.380552e+03
# std                0.660443    937.799129     4.259871e+04
# ...

# %%
data.columns
# Out:
# Index(['customer_id', 'vintage', 'age', 'gender', 'dependents', 'occupation',
#        'city', 'customer_nw_category', 'branch_code', 'current_balance',
#        'previous_month_end_balance', 'average_monthly_balance_prevQ',
#        'average_monthly_balance_prevQ2', 'current_month_credit',
#        'previous_month_credit', 'current_month_debit', 'previous_month_debit',
#        'current_month_balance', 'previous_month_balance', 'churn',
#        'last_transaction'],
#       dtype='object')

# %%
data.dtypes
# Out:
# customer_id                         int64
# vintage                             int64
# age                                 int64
# gender                             object
# dependents                        float64
# occupation                         object
# city                              float64
# customer_nw_category                int64
# branch_code                         int64
# current_balance                   float64
# previous_month_end_balance        float64
# average_monthly_balance_prevQ     float64
# average_monthly_balance_prevQ2    float64
# current_month_credit              float64
# previous_month_credit             float64
# current_month_debit               float64
# previous_month_debit              float64
# current_month_balance             float64
# previous_month_balance            float64
# churn                               int64
# last_transaction                   object
# dtype: object

# %% [markdown]
# # 2 - Identify variable types

# %% [markdown]
# ## Integer Data Type

# %%
data.dtypes[data.dtypes =='int64']
# Out:
# customer_id             int64
# vintage                 int64
# age                     int64
# customer_nw_category    int64
# branch_code             int64
# churn                   int64
# dtype: object

# %% [markdown]
# ### NOTES
# * Customer_id, vintage, age is okay for integer
# * cutsomer_nw_category (ordinal) and branch_code (nominal) and churn (binary) (nominal) must be converted to categorical variable

# %%
data.customer_nw_category.value_counts()
# Out:
# 2    14559
# 3    10112
# 1     3711
# Name: customer_nw_category, dtype: int64

# %%
data.branch_code.value_counts().head()
# Out:
# 19    145
# 6     142
# 60    128
# 16    111
# 8     109
# Name: branch_code, dtype: int64

# %% [markdown]
# ### Converting to categorical datatype

# %%
data['customer_nw_category']=data['customer_nw_category'].astype('category')
data['branch_code']=data['branch_code'].astype('category')
data['churn']=data['churn'].astype('category')

# %% [markdown]
# ## Float Variables

# %%
data.dtypes[data.dtypes=='float64']
# Out:
# dependents                        float64
# city                              float64
# current_balance                   float64
# previous_month_end_balance        float64
# average_monthly_balance_prevQ     float64
# average_monthly_balance_prevQ2    float64
# current_month_credit              float64
# previous_month_credit             float64
# current_month_debit               float64
# previous_month_debit              float64
# current_month_balance             float64
# previous_month_balance            float64
# dtype: object

# %% [markdown]
# ### NOTES
# * City is a category (nominal) as there are various cities
# * dependents must be a whole number. so would need to be converted to integer

# %%
#data['dependents'].fillna(-1)
data['city']=data['city'].astype('category')
data['dependents']=data['dependents'].astype('Int64')

# %% [markdown]
# ## Object Variables

# %%
data.dtypes[data.dtypes=='object']
# Out:
# gender              object
# occupation          object
# last_transaction    object
# dtype: object

# %% [markdown]
# ### NOTES
#
# * Gender and occupation are categorical variables
# * last_transaction must be  date time variable

# %%
data['gender']=data['gender'].astype('category')
data['occupation']=data['occupation'].astype('category')

# %% [markdown]
# ## Datetime Variables

# %%
date=pd.DatetimeIndex(data['last_transaction'])

# %%
# Extracting date features using date object created. Breaking down the last transaction will help us in understanding 
# when the last transaction was done from different perspectives
# Note - We dont need year as all data is from 2019 year
data['day_of_year']=date.dayofyear
data['week_of_year']=date.weekofyear
data['month_of_year']=date.month
data['date']=date.day
data['day_of_week']=date.dayofweek

# %%
data.head()
# Out:
#    customer_id  vintage  age gender  dependents     occupation    city  \
# 0            1     2101   66   Male           0  self_employed   187.0
# 1            2     2348   35   Male           0  self_employed     NaN
# 2            4     2194   31   Male           0       salaried   146.0
# 3            5     2329   90    NaN        <NA>  self_employed  1020.0
# 4            6     1579   42   Male           2  self_employed  1494.0
#
#   customer_nw_category branch_code  current_balance  ...  \
# 0                    2         755          1458.71  ...
# 1                    2        3214          5390.37  ...
# 2                    2          41          3913.16  ...
# 3                    2         582          2291.91  ...
# 4                    3         388           927.72  ...
#
#    previous_month_debit  current_month_balance  previous_month_balance  churn  \
# 0                  0.20                1458.71                 1458.71      0
# ...

# %%
# Now that we have all features of date, we can drop last_transaction column

data.drop('last_transaction',inplace=True,axis=1)

# %%
data.head()
# Out:
#    customer_id  vintage  age gender  dependents     occupation    city  \
# 0            1     2101   66   Male           0  self_employed   187.0
# 1            2     2348   35   Male           0  self_employed     NaN
# 2            4     2194   31   Male           0       salaried   146.0
# 3            5     2329   90    NaN        <NA>  self_employed  1020.0
# 4            6     1579   42   Male           2  self_employed  1494.0
#
#   customer_nw_category branch_code  current_balance  ...  current_month_debit  \
# 0                    2         755          1458.71  ...                 0.20
# 1                    2        3214          5390.37  ...              5486.27
# 2                    2          41          3913.16  ...              6046.73
# 3                    2         582          2291.91  ...                 0.47
# 4                    3         388           927.72  ...               588.62
#
# ...
